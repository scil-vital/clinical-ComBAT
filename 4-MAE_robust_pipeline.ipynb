# %% [markdown]
# # Notebook 4 - Harmonisation robuste (MAE)
# Pipeline pour tester l'harmonisation avec toutes les méthodes robustes et calculer le MAE.

# %%
import os
import pandas as pd
from joblib import Parallel, delayed

from robust_evaluation_tools.robust_utils import get_site, get_camcan_file, get_metrics, remove_covariates_effects_metrics
from robust_evaluation_tools.robust_harmonization import fit, apply, compare_with_compilation, compare_with_compilation_SMAPE, compare_with_compilation_STD, compare_with_compilation_var
from robust_evaluation_tools.robust_outlier_detection import z_score_detection, mad_detection, flag_sid
from robust_evaluation_tools.robust_MLP import predict_malades_MLP

# %%
# Paramètres
MAINFOLDER = "RESULTS/MAE_TEST"
base_name = "harmonized"
augmentation_copies = 5
augmentation_suffix = f"_AUG_{augmentation_copies}" if augmentation_copies else ""
SYNTHETIC_SITES = f"DONNES/processed/synthetic_sites/{base_name}{augmentation_suffix}"
SYNTHETIC_SITES_VERSION = "v1"

SMAPE_ONLY = False
harmonization_method = "classic"

metrics = get_metrics()
# diseases = get_diseases(True)
diseases = ["ALL"]

BASE_METHODS = ["No", "raw"]
ROBUST_METHODS = [
    "IQR",
    "MAD",
    "SN",
    "QN",
    "MMS",
    "VS",
    "FLIP",
    "G_MAD",
    "G_ZS",
    "ZS",
    "MLP7_ALL"
]
ALL_METHODS = BASE_METHODS + ROBUST_METHODS

# sample_sizes = [100]  # Mettre à None pour autodétection dans l'arborescence
# disease_ratios = [0.03, 0.1, 0.3, 0.5, 0.7, 0.8]  # Mettre à None pour autodétection dans l'arborescence
# num_tests = 20  # Mettre à None pour autodétection dans l'arborescence
n_jobs_number = -1

sample_sizes = None
disease_ratios = None
num_tests = None

# %% [markdown]
# ## Fonctions d'harmonisation

# %%
def harmonize(f_train, ref_data_file, metric, harmonizartion_method, f_test, directory, method, robust, rwp, hc, gt_train_file_name, gt_test_file_name):
    # chemin de sortie
    dir_path = os.path.join(directory, robust) if method == 'robust' else os.path.join(directory, method)

    # obtention des fichiers transformés
    if robust == 'raw':
        output_filename_train = f_train
        output_filename_test = f_test
    else:
        output_model_filename = fit(f_train, ref_data_file, metric, harmonizartion_method, robust, rwp, dir_path, hc)
        output_filename_train = apply(f_train, output_model_filename, metric, harmonizartion_method, robust, rwp, dir_path)
        output_filename_test = apply(f_test, output_model_filename, metric, harmonizartion_method, robust, rwp, dir_path)

    # lire une seule fois les csv nécessaires
    out_train_df = pd.read_csv(output_filename_train)
    out_test_df = pd.read_csv(output_filename_test)
    gt_train_df = pd.read_csv(gt_train_file_name)
    gt_test_df = pd.read_csv(gt_test_file_name)

    # calculs standards
    std_mae_train = compare_with_compilation_STD(out_train_df, gt_train_df)
    std_mae_test = compare_with_compilation_STD(out_test_df, gt_test_df)

    if not SMAPE_ONLY:
        smape_train = compare_with_compilation_SMAPE(out_train_df, gt_train_df)
        smape_test = compare_with_compilation_SMAPE(out_test_df, gt_test_df)

        mae_train = compare_with_compilation(out_train_df, gt_train_df)
        maev_train = compare_with_compilation_var(out_train_df, gt_train_df)

        mae_test = compare_with_compilation(out_test_df, gt_test_df)
        maev_test = compare_with_compilation_var(out_test_df, gt_test_df)
    else:
        mae_test = pd.DataFrame()
        maev_test = pd.DataFrame()
        mae_train = pd.DataFrame()
        maev_train = pd.DataFrame()
        smape_test = pd.DataFrame()
        smape_train = pd.DataFrame()

    # ajout des métadonnées de façon concise
    meta_cols = {'site': get_site(f_train), 'method': method, 'robust_method': robust}
    for df in (mae_test, maev_test, mae_train, maev_train, smape_test, smape_train, std_mae_test, std_mae_train):
        for k, v in meta_cols.items():
            df[k] = v

    return mae_test, maev_test, mae_train, maev_train, smape_test, smape_train, std_mae_test, std_mae_train


def analyse_site(f_train, f_test, robust_methods, directory, ref_data_file, metric, harmonizartion_method, gt_train_file_name, gt_test_file_name):
    df_mae_test_robust = pd.DataFrame()
    df_maev_test_robust = pd.DataFrame()
    df_mae_train_robust = pd.DataFrame()
    df_maev_train_robust = pd.DataFrame()
    df_smape_test_robust = pd.DataFrame()
    df_smape_train_robust = pd.DataFrame()
    df_std_mae_test_robust = pd.DataFrame()
    df_std_mae_train_robust = pd.DataFrame()

    for robust in robust_methods:
        if robust == 'raw':
            (mae_test, maev_test, mae_train, maev_train, smape_test, smape_train, std_mae_test, std_mae_train) = harmonize(
                f_train, ref_data_file, metric, harmonizartion_method, f_test, directory, 'raw', 'raw', False, False, gt_train_file_name, gt_test_file_name
            )
        elif robust == 'No':
            (mae_test_hc, maev_test_hc, mae_train_hc, maev_train_hc, smape_test_hc, smape_train_hc, std_mae_test_hc, std_mae_train_hc) = harmonize(
                f_train, ref_data_file, metric, harmonizartion_method, f_test, directory, 'hc', 'No', False, True, gt_train_file_name, gt_test_file_name
            )
            (mae_test_no, maev_test_no, mae_train_no, maev_train_no, smape_test_no, smape_train_no, std_mae_test_no, std_mae_train_no) = harmonize(
                f_train, ref_data_file, metric, harmonizartion_method, f_test, directory, 'NoRobust', 'No', False, False, gt_train_file_name, gt_test_file_name
            )

            mae_test = pd.concat([mae_test_no, mae_test_hc], ignore_index=True)
            maev_test = pd.concat([maev_test_no, maev_test_hc], ignore_index=True)
            mae_train = pd.concat([mae_train_no, mae_train_hc], ignore_index=True)
            maev_train = pd.concat([maev_train_no, maev_train_hc], ignore_index=True)
            smape_test = pd.concat([smape_test_no, smape_test_hc], ignore_index=True)
            smape_train = pd.concat([smape_train_no, smape_train_hc], ignore_index=True)
            std_mae_test = pd.concat([std_mae_test_no, std_mae_test_hc], ignore_index=True)
            std_mae_train = pd.concat([std_mae_train_no, std_mae_train_hc], ignore_index=True)
        else:
            (mae_test, maev_test, mae_train, maev_train, smape_test, smape_train, std_mae_test, std_mae_train) = harmonize(
                f_train, ref_data_file, metric, harmonizartion_method, f_test, directory, 'robust', robust, False, False, gt_train_file_name, gt_test_file_name
            )

        df_mae_test_robust = pd.concat([df_mae_test_robust, mae_test], ignore_index=True)
        df_maev_test_robust = pd.concat([df_maev_test_robust, maev_test], ignore_index=True)
        df_mae_train_robust = pd.concat([df_mae_train_robust, mae_train], ignore_index=True)
        df_maev_train_robust = pd.concat([df_maev_train_robust, maev_train], ignore_index=True)
        df_smape_test_robust = pd.concat([df_smape_test_robust, smape_test], ignore_index=True)
        df_smape_train_robust = pd.concat([df_smape_train_robust, smape_train], ignore_index=True)
        df_std_mae_test_robust = pd.concat([df_std_mae_test_robust, std_mae_test], ignore_index=True)
        df_std_mae_train_robust = pd.concat([df_std_mae_train_robust, std_mae_train], ignore_index=True)

    return (df_mae_test_robust, df_maev_test_robust, df_mae_train_robust, df_maev_train_robust, df_smape_test_robust, df_smape_train_robust, df_std_mae_test_robust, df_std_mae_train_robust)


def process_analysis(disease, sample_size, disease_ratio, test_index, harmonization_method, SYNTHETIC_SITES_VERSION, metrics, robust_methods):
    sizeDir = os.path.join(MAINFOLDER, f'PROCESS', harmonization_method, disease, f"{sample_size}_{int(disease_ratio * 100)}", f"{test_index}")
    mae_test_file_path = os.path.join(sizeDir, 'mae_compilation_test.csv')
    maev_test_file_path = os.path.join(sizeDir, 'maev_compilation_test.csv')
    mae_train_file_path = os.path.join(sizeDir, 'mae_compilation_train.csv')
    maev_train_file_path = os.path.join(sizeDir, 'maev_compilation_train.csv')
    smape_test_file_path = os.path.join(sizeDir, 'smape_compilation_test.csv')
    smape_train_file_path = os.path.join(sizeDir, 'smape_compilation_train.csv')
    std_mae_train_file_path = os.path.join(sizeDir, 'std_mae_compilation_train.csv')
    std_mae_test_file_path = os.path.join(sizeDir, 'std_mae_compilation_test.csv')

    def _load_if_exists(path):
        return pd.read_csv(path) if os.path.isfile(path) else pd.DataFrame()

    mae_compilation_test = _load_if_exists(mae_test_file_path)
    maev_compilation_test = _load_if_exists(maev_test_file_path)
    mae_compilation_train = _load_if_exists(mae_train_file_path)
    maev_compilation_train = _load_if_exists(maev_train_file_path)
    smape_compilation_test = _load_if_exists(smape_test_file_path)
    smape_compilation_train = _load_if_exists(smape_train_file_path)
    std_mae_compilation_train = _load_if_exists(std_mae_train_file_path)
    std_mae_compilation_test = _load_if_exists(std_mae_test_file_path)

    methods_to_run = robust_methods
    if not std_mae_compilation_test.empty:
        existing_methods = set(std_mae_compilation_test['robust_method'].unique())
        missing_methods = [m for m in methods_to_run if m not in existing_methods]
        if not missing_methods:
            print(f"✔️ Toutes les méthodes déjà traitées pour {disease} {sample_size}_{int(disease_ratio*100)} test_index {test_index}.")
            return (mae_test_file_path, maev_test_file_path, mae_train_file_path, maev_train_file_path, smape_test_file_path, smape_train_file_path, std_mae_test_file_path, std_mae_train_file_path)
        methods_to_run = missing_methods

    directory_site = os.path.join(SYNTHETIC_SITES, disease)
    sizeDir_site = os.path.join(directory_site, f"{sample_size}_{int(disease_ratio * 100)}")
    tempDir_site = os.path.join(sizeDir_site, f"{test_index}")

    df_for_tags = pd.read_csv(os.path.join(tempDir_site, f"train_{sample_size}_{int(disease_ratio * 100)}_{test_index}_all.csv"))
    df_for_tags = df_for_tags[~df_for_tags['bundle'].isin(['left_ventricle', 'right_ventricle'])]
    df_for_tags = remove_covariates_effects_metrics(df_for_tags)

    z_score_sids = z_score_detection(df_for_tags)
    mad_sids = mad_detection(df_for_tags)

    models = ['mlp7_ALL']
    preds = {m.upper(): predict_malades_MLP(df_for_tags, m) for m in models}

    for metric in metrics:
        tempDir = os.path.join(sizeDir, metric)
        os.makedirs(tempDir, exist_ok=True)

        train_file_name = f"train_{sample_size}_{int(disease_ratio * 100)}_{test_index}_{metric}.csv"
        test_file_name = f"test_{sample_size}_{int(disease_ratio * 100)}_{test_index}_{metric}.csv"
        gt_train_file_name = os.path.join(tempDir_site, f"gt_train_{sample_size}_{int(disease_ratio * 100)}_{test_index}_{metric}.csv")
        gt_test_file_name = os.path.join(tempDir_site, f"gt_test_{sample_size}_{int(disease_ratio * 100)}_{test_index}_{metric}.csv")

        train_file = os.path.join(tempDir_site, train_file_name)
        train_df = pd.read_csv(train_file)
        train_df = train_df[~train_df['bundle'].isin(['left_ventricle', 'right_ventricle'])]
        train_df = train_df.drop(columns=['mean_no_cov', 'metric_bundle'], errors='ignore')
        train_df = flag_sid(train_df, z_score_sids, 'G_ZS')
        train_df = flag_sid(train_df, mad_sids, 'G_MAD')
        for label, sid_list in preds.items():
            train_df = flag_sid(train_df, sid_list, label)

        train_df['site'] = disease + '_' + train_df['site']
        new_train_file = os.path.join(tempDir, train_file_name)
        train_df.to_csv(new_train_file, index=False)

        test_file = os.path.join(tempDir_site, test_file_name)
        test_df = pd.read_csv(test_file)
        test_df = test_df[~test_df['bundle'].isin(['left_ventricle', 'right_ventricle'])]
        test_df = test_df.drop(columns=['mean_no_cov', 'metric_bundle'], errors='ignore')
        test_df['site'] = train_df['site']
        new_test_file = os.path.join(tempDir, test_file_name)
        test_df.to_csv(new_test_file, index=False)

        ref_data_file = get_camcan_file(metric, cleaned=True)

        mae_analyze_test, maev_analyze_test, mae_analyze_train, maev_analyze_train, smape_analyze_test, smape_analyze_train, std_mae_analyze_test, std_mae_analyze_train = analyse_site(
            new_train_file, new_test_file, methods_to_run, tempDir, ref_data_file, metric, harmonization_method, gt_train_file_name, gt_test_file_name
        )

        for df in [mae_analyze_test, maev_analyze_test, mae_analyze_train, maev_analyze_train, smape_analyze_test, smape_analyze_train, std_mae_analyze_test, std_mae_analyze_train]:
            df['disease'] = disease
            df['metric'] = metric

        std_mae_compilation_test = pd.concat([std_mae_compilation_test, std_mae_analyze_test], ignore_index=True).drop_duplicates()
        std_mae_compilation_train = pd.concat([std_mae_compilation_train, std_mae_analyze_train], ignore_index=True).drop_duplicates()
        if not SMAPE_ONLY:
            mae_compilation_test = pd.concat([mae_compilation_test, mae_analyze_test], ignore_index=True).drop_duplicates()
            maev_compilation_test = pd.concat([maev_compilation_test, maev_analyze_test], ignore_index=True).drop_duplicates()
            mae_compilation_train = pd.concat([mae_compilation_train, mae_analyze_train], ignore_index=True).drop_duplicates()
            maev_compilation_train = pd.concat([maev_compilation_train, maev_analyze_train], ignore_index=True).drop_duplicates()
            smape_compilation_test = pd.concat([smape_compilation_test, smape_analyze_test], ignore_index=True).drop_duplicates()
            smape_compilation_train = pd.concat([smape_compilation_train, smape_analyze_train], ignore_index=True).drop_duplicates()

    os.makedirs(sizeDir, exist_ok=True)
    std_mae_compilation_test.to_csv(std_mae_test_file_path, index=False)
    std_mae_compilation_train.to_csv(std_mae_train_file_path, index=False)
    if not SMAPE_ONLY:
        mae_compilation_test.to_csv(mae_test_file_path, index=False)
        maev_compilation_test.to_csv(maev_test_file_path, index=False)
        mae_compilation_train.to_csv(mae_train_file_path, index=False)
        maev_compilation_train.to_csv(maev_train_file_path, index=False)
        smape_compilation_test.to_csv(smape_test_file_path, index=False)
        smape_compilation_train.to_csv(smape_train_file_path, index=False)



def infer_experiment_settings(base_dir, diseases):
    sample_sizes = set()
    disease_ratios = set()
    inferred_num_tests = 0

    for disease in diseases:
        disease_dir = os.path.join(base_dir, disease)
        if not os.path.isdir(disease_dir):
            continue

        for size_ratio_name in os.listdir(disease_dir):
            size_ratio_path = os.path.join(disease_dir, size_ratio_name)
            if not os.path.isdir(size_ratio_path) or '_' not in size_ratio_name:
                continue

            size_part, ratio_part = size_ratio_name.split('_', 1)
            try:
                sample_size_val = int(size_part)
                ratio_val = int(ratio_part) / 100
            except ValueError:
                continue

            sample_sizes.add(sample_size_val)
            disease_ratios.add(ratio_val)

            possible_tests = [
                int(p)
                for p in os.listdir(size_ratio_path)
                if p.isdigit() and os.path.isdir(os.path.join(size_ratio_path, p))
            ]
            if possible_tests:
                inferred_num_tests = max(inferred_num_tests, max(possible_tests) + 1, len(possible_tests))

    if not sample_sizes or not disease_ratios or inferred_num_tests == 0:
        raise ValueError(f"Impossible de déduire les paramètres depuis {base_dir} pour les maladies {diseases}.")

    return sorted(sample_sizes), sorted(disease_ratios), inferred_num_tests

def analyse_method(sample_sizes, disease_ratios, num_tests, robust_methods, diseases, metrics, harmonization_method, SYNTHETIC_SITES_VERSION, n_jobs=-1):
    if sample_sizes is None or disease_ratios is None or num_tests is None:
        inferred_sample_sizes, inferred_disease_ratios, inferred_num_tests = infer_experiment_settings(SYNTHETIC_SITES, diseases)
        sample_sizes = inferred_sample_sizes if sample_sizes is None else sample_sizes
        disease_ratios = inferred_disease_ratios if disease_ratios is None else disease_ratios
        num_tests = inferred_num_tests if num_tests is None else num_tests

    tasks = [
        (disease, sample_size, disease_ratio, num_test, harmonization_method, SYNTHETIC_SITES_VERSION, metrics, robust_methods)
        for disease in diseases
        for sample_size in sample_sizes
        for disease_ratio in disease_ratios
        for num_test in range(num_tests)
    ]

    Parallel(n_jobs=n_jobs)(delayed(process_analysis)(*task) for task in tasks)

# %% [markdown]
# ## Lancement de l'analyse

# %%
analyse_method(sample_sizes, disease_ratios, num_tests, ALL_METHODS, diseases, metrics, harmonization_method, SYNTHETIC_SITES_VERSION, n_jobs=n_jobs_number)
# Out:
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_3 test_index 1.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_3 test_index 6.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_3 test_index 8.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_3 test_index 17.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_3 test_index 24.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_3 test_index 25.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_3 test_index 26.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_3 test_index 10.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_3 test_index 23.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_3 test_index 22.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_3 test_index 7.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_3 test_index 27.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_3 test_index 28.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_3 test_index 0.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_3 test_index 18.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_3 test_index 30.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_3 test_index 29.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_3 test_index 4.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_3 test_index 14.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_3 test_index 31.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_3 test_index 9.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_3 test_index 32.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_3 test_index 11.✔️ Toutes les méthodes déjà traitées pour ALL 100_3 test_index 21.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_3 test_index 33.
#
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_3 test_index 16.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_3 test_index 34.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_3 test_index 35.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_3 test_index 36.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_3 test_index 3.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_3 test_index 37.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_3 test_index 13.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_3 test_index 15.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_3 test_index 39.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_3 test_index 12.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_3 test_index 38.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_10 test_index 1.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_3 test_index 20.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_3 test_index 19.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_3 test_index 2.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_10 test_index 3.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_3 test_index 5.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_10 test_index 2.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_10 test_index 4.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_10 test_index 0.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_10 test_index 5.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_10 test_index 8.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_10 test_index 7.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_10 test_index 9.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_10 test_index 6.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_10 test_index 12.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_10 test_index 11.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_10 test_index 14.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_10 test_index 16.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_10 test_index 17.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_10 test_index 15.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_10 test_index 13.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_10 test_index 18.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_10 test_index 10.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_10 test_index 19.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_10 test_index 20.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_10 test_index 24.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_10 test_index 22.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_10 test_index 25.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_10 test_index 23.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_10 test_index 28.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_10 test_index 27.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_10 test_index 29.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_10 test_index 21.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_10 test_index 31.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_10 test_index 32.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_10 test_index 34.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_10 test_index 37.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_10 test_index 30.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_10 test_index 26.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_10 test_index 36.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_10 test_index 38.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_10 test_index 33.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_10 test_index 35.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_30 test_index 0.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_10 test_index 39.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_30 test_index 1.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_30 test_index 2.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_30 test_index 4.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_30 test_index 6.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_30 test_index 3.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_30 test_index 5.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_30 test_index 8.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_30 test_index 7.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_30 test_index 9.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_30 test_index 12.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_30 test_index 10.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_30 test_index 11.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_30 test_index 14.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_30 test_index 13.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_30 test_index 16.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_30 test_index 15.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_30 test_index 17.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_30 test_index 19.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_30 test_index 18.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_30 test_index 20.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_30 test_index 21.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_30 test_index 22.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_30 test_index 23.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_30 test_index 25.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_30 test_index 24.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_30 test_index 26.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_30 test_index 29.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_30 test_index 28.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_30 test_index 27.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_30 test_index 30.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_30 test_index 31.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_30 test_index 32.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_30 test_index 33.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_30 test_index 34.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_30 test_index 35.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_30 test_index 36.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_30 test_index 38.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_50 test_index 1.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_30 test_index 37.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_50 test_index 0.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_30 test_index 39.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_50 test_index 5.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_50 test_index 2.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_50 test_index 3.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_50 test_index 4.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_50 test_index 6.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_50 test_index 7.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_50 test_index 8.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_50 test_index 9.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_50 test_index 10.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_50 test_index 11.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_50 test_index 12.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_50 test_index 13.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_50 test_index 14.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_50 test_index 16.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_50 test_index 15.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_50 test_index 17.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_50 test_index 18.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_50 test_index 20.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_50 test_index 19.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_50 test_index 21.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_50 test_index 23.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_50 test_index 22.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_50 test_index 26.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_50 test_index 25.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_50 test_index 24.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_50 test_index 28.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_50 test_index 30.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_50 test_index 27.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_50 test_index 29.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_50 test_index 35.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_50 test_index 31.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_50 test_index 32.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_50 test_index 33.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_50 test_index 34.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_50 test_index 36.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_50 test_index 37.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_50 test_index 38.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_50 test_index 39.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_70 test_index 0.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_70 test_index 4.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_70 test_index 2.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_70 test_index 3.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_70 test_index 1.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_70 test_index 5.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_70 test_index 6.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_70 test_index 7.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_70 test_index 8.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_70 test_index 10.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_70 test_index 12.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_70 test_index 14.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_70 test_index 18.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_70 test_index 20.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_70 test_index 24.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_70 test_index 16.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_70 test_index 22.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_70 test_index 30.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_70 test_index 26.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_70 test_index 11.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_70 test_index 28.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_70 test_index 32.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_70 test_index 9.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_70 test_index 36.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_70 test_index 34.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_70 test_index 13.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_70 test_index 15.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_70 test_index 21.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_80 test_index 0.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_70 test_index 19.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_70 test_index 25.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_70 test_index 23.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_70 test_index 38.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_80 test_index 4.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_70 test_index 27.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_70 test_index 17.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_70 test_index 29.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_80 test_index 2.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_70 test_index 31.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_70 test_index 37.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_80 test_index 10.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_80 test_index 6.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_70 test_index 33.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_70 test_index 35.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_80 test_index 12.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_80 test_index 14.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_80 test_index 17.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_80 test_index 1.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_80 test_index 8.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_80 test_index 18.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_80 test_index 5.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_70 test_index 39.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_80 test_index 16.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_80 test_index 19.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_80 test_index 23.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_80 test_index 22.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_80 test_index 20.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_80 test_index 21.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_80 test_index 3.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_80 test_index 7.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_80 test_index 11.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_80 test_index 25.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_80 test_index 27.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_80 test_index 15.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_80 test_index 13.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_80 test_index 26.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_80 test_index 24.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_80 test_index 28.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_80 test_index 30.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_80 test_index 29.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_80 test_index 9.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_80 test_index 34.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_80 test_index 31.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_80 test_index 33.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_80 test_index 32.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_80 test_index 36.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_80 test_index 35.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_80 test_index 37.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_80 test_index 38.
# ✔️ Toutes les méthodes déjà traitées pour ALL 100_80 test_index 39.

# %%
harmonization_method = "clinic"
analyse_method(sample_sizes, disease_ratios, num_tests, ALL_METHODS, diseases, metrics, harmonization_method, SYNTHETIC_SITES_VERSION, n_jobs=n_jobs_number)
# Out:
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method IQR
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method MAD
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method SN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method QN
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method MMS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method VS
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method FLIP
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_MAD
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method ZS
# Removing outliers with method G_ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method G_ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method MLP7_ALL
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method ZS
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method MAD
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method IQR
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method SN
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method MAD
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method QN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method SN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method MMS
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method QN
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method VS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method MMS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method MMS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method FLIP
# Removing outliers with method VS
# Removing outliers with method FLIP
# Removing outliers with method VS
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method VS
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method VS
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method FLIP
# Removing outliers with method G_MAD
# Removing outliers with method FLIP
# Removing outliers with method G_MAD
# Removing outliers with method FLIP
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method FLIP
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_MAD
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_MAD
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method ZS
# Removing outliers with method G_ZS
# Removing outliers with method ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method G_ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method G_ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method MLP7_ALL
# Removing outliers with method ZS
# Removing outliers with method MLP7_ALL
# Removing outliers with method ZS
# Removing outliers with method MLP7_ALL
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method ZS
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method MAD
# Removing outliers with method IQR
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method MAD
# Removing outliers with method IQR
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method IQR
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method SN
# Removing outliers with method MAD
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method MAD
# Removing outliers with method SN
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method MAD
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method QN
# Removing outliers with method SN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method QN
# Removing outliers with method SN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method SN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method MMS
# Removing outliers with method QN
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method MMS
# Removing outliers with method QN
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method QN
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method VS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method VS
# Removing outliers with method MMS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method MMS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method VSRemoving outliers with method VS
#
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method VS
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method FLIP
# Removing outliers with method G_MAD
# Removing outliers with method FLIP
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method FLIP
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_ZS
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_MAD
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method G_ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method MLP7_ALL
# Removing outliers with method ZS
# Removing outliers with method MLP7_ALL
# Removing outliers with method ZS
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method ZS
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method ZS
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method MAD
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method MAD
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method MAD
# Removing outliers with method IQR
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method IQR
# Removing outliers with method SN
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method SN
# Removing outliers with method MAD
# Removing outliers with method SN
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method MAD
# Removing outliers with method QN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method QN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method QN
# Removing outliers with method SN
# Removing outliers with method SN
# ...
# Removing outliers with method G_MAD
# Removing outliers with method SN
# Removing outliers with method IQR
# Removing outliers with method MMS
# Removing outliers with method G_MAD
# Removing outliers with method MAD
# Removing outliers with method IQR
# Removing outliers with method G_MAD
# Removing outliers with method ZS
# Removing outliers with method MMS
# Removing outliers with method G_ZS
# Removing outliers with method ZS
# Removing outliers with method IQR
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method ZS
# Removing outliers with method VS
# Removing outliers with method G_MAD
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method ZS
# Removing outliers with method FLIP
# Removing outliers with method IQR
# Removing outliers with method ZS
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method G_ZS
# Removing outliers with method QN
# Removing outliers with method G_ZS
# Removing outliers with method VS
# Removing outliers with method MAD
# Removing outliers with method G_ZS
# Removing outliers with method MAD
# Removing outliers with method G_ZS
# Removing outliers with method SN
# Removing outliers with method VS
# Removing outliers with method MLP7_ALL
# Removing outliers with method ZS
# Removing outliers with method MLP7_ALL
# Removing outliers with method MAD
# Removing outliers with method G_ZS
# Removing outliers with method MLP7_ALL
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method FLIP
# Removing outliers with method G_MAD
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MAD
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method ZS
# Removing outliers with method MMS
# Removing outliers with method ZS
# Removing outliers with method FLIP
# Removing outliers with method SN
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method SN
# Removing outliers with method QN
# Removing outliers with method FLIP
# Removing outliers with method MLP7_ALL
# Removing outliers with method SN
# Removing outliers with method ZS
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method G_MAD
# Removing outliers with method G_ZS
# Removing outliers with method IQR
# Removing outliers with method SN
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method MLP7_ALL
# Removing outliers with method VS
# Removing outliers with method MLP7_ALL
# Removing outliers with method G_MAD
# Removing outliers with method QN
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method QN
# Removing outliers with method G_MAD
# Removing outliers with method MMS
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method QN
# Removing outliers with method MLP7_ALL
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method ZS
# Removing outliers with method MAD
# Removing outliers with method G_ZS
# Removing outliers with method QN
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method FLIP
# Removing outliers with method G_ZS
# Removing outliers with method MMS
# Removing outliers with method IQR
# Removing outliers with method MMS
# Removing outliers with method G_ZS
# Removing outliers with method VS
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method IQR
# Removing outliers with method MMS
# Removing outliers with method IQR
# Removing outliers with method SN
# Removing outliers with method MLP7_ALL
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method ZS
# Removing outliers with method MMS
# Removing outliers with method G_MAD
# Removing outliers with method ZS
# Removing outliers with method IQR
# Removing outliers with method VS
# Removing outliers with method ZS
# Removing outliers with method MAD
# Removing outliers with method VS
# Removing outliers with method FLIP
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method SN
# Removing outliers with method SN
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method MAD
# Removing outliers with method VS
# Removing outliers with method MAD
# Removing outliers with method QN
# Removing outliers with method MLP7_ALL
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method VS
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method G_ZS
# Removing outliers with method MLP7_ALL
# Removing outliers with method MAD
# Removing outliers with method FLIP
# Removing outliers with method MLP7_ALL
# Removing outliers with method FLIP
# Removing outliers with method SN
# Removing outliers with method G_MAD
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method IQR
# Removing outliers with method QN
# Removing outliers with method QN
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method SN
# Removing outliers with method SN
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method MMS
# Removing outliers with method FLIP
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method FLIP
# Removing outliers with method MAD
# Removing outliers with method ZS
# Removing outliers with method MAD
# Removing outliers with method SN
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_ZS
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method MAD
# Removing outliers with method MMS
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method MMS
# Removing outliers with method IQR
# Removing outliers with method QN
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method QN
# Removing outliers with method VS
# Removing outliers with method G_MAD
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method G_MAD
# Removing outliers with method SN
# Removing outliers with method MLP7_ALL
# Removing outliers with method SN
# Removing outliers with method QN
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method ZS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method SN
# Removing outliers with method MMS
# Removing outliers with method VS
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method VS
# Removing outliers with method MAD
# Removing outliers with method MMS
# Removing outliers with method IQR
# Removing outliers with method MMS
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method G_ZS
# Removing outliers with method FLIP
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method G_ZS
# Removing outliers with method IQR
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method IQR
# Removing outliers with method ZS
# Removing outliers with method MMS
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method ZS
# Removing outliers with method MLP7_ALL
# Removing outliers with method VS
# Removing outliers with method QN
# Removing outliers with method VS
# Removing outliers with method FLIP
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method VS
# Removing outliers with method FLIP
# Removing outliers with method SN
# Removing outliers with method VS
# Removing outliers with method MAD
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method VS
# Removing outliers with method G_MAD
# Removing outliers with method ZS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method ZS
# Removing outliers with method MAD
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MAD
# Removing outliers with method VS
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method G_MAD
# Removing outliers with method MMS
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method G_MAD
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method SN
# Removing outliers with method QN
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method G_ZS
# Removing outliers with method FLIP
# Removing outliers with method MLP7_ALL
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method MLP7_ALL
# Removing outliers with method IQR
# Removing outliers with method SN
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method SN
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method FLIP
# Removing outliers with method G_ZS
# Removing outliers with method VS
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_ZS
# Removing outliers with method G_MAD
# Removing outliers with method MMS
# Removing outliers with method QN
# Removing outliers with method G_MAD
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method G_MAD
# Removing outliers with method ZS
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method MAD
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method G_MAD
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method FLIP
# Removing outliers with method ZS
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method MMS
# Removing outliers with method ZS
# Removing outliers with method VS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method MLP7_ALL
# Removing outliers with method G_MAD
# Removing outliers with method MMS
# Removing outliers with method G_MAD
# Removing outliers with method IQR
# Removing outliers with method SN
# Removing outliers with method G_MAD
# Removing outliers with method G_ZS
# Removing outliers with method G_MAD
# Removing outliers with method MMS
# Removing outliers with method G_MAD
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method MLP7_ALL
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method ZS
# Removing outliers with method FLIP
# Removing outliers with method VS
# Removing outliers with method MLP7_ALL
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method VS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method QN
# Removing outliers with method ZS
# Removing outliers with method MAD
# Removing outliers with method VS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method G_MAD
# Removing outliers with method MLP7_ALL
# Removing outliers with method FLIP
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method FLIP
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method MLP7_ALL
# Removing outliers with method MMS
# Removing outliers with method SN
# Removing outliers with method FLIP
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method G_ZS
# Removing outliers with method G_MAD
# Removing outliers with method MLP7_ALL
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method MLP7_ALL
# Removing outliers with method VS
# Removing outliers with method MLP7_ALL
# Removing outliers with method QN
# Removing outliers with method MLP7_ALL
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method MLP7_ALL
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method IQR
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method G_ZS
# Removing outliers with method ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method MMS
# Removing outliers with method FLIP
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method MAD
# Removing outliers with method ZS
# Removing outliers with method MLP7_ALL
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method G_MAD
# Removing outliers with method VS
# Removing outliers with method SN
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method G_ZS
# Removing outliers with method FLIP
# Removing outliers with method QN
# Removing outliers with method ZS
# Removing outliers with method G_MAD
# Removing outliers with method MMS
# Removing outliers with method MLP7_ALL
# Removing outliers with method G_ZS
# Removing outliers with method VS
# Removing outliers with method ZS
# Removing outliers with method FLIP
# Removing outliers with method MLP7_ALL
# Removing outliers with method G_MAD
# Removing outliers with method G_ZS
# Removing outliers with method ZS
# Removing outliers with method MLP7_ALL

# %%
harmonization_method = "gam"
analyse_method(sample_sizes, disease_ratios, num_tests, ALL_METHODS, diseases, metrics, harmonization_method, SYNTHETIC_SITES_VERSION, n_jobs=n_jobs_number)
# Out:
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# FLIPPERRRRRRRR
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# FLIPPERRRRRRRR
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# Removing outliers with method FLIP
# FLIPPERRRRRRRR
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# FLIPPERRRRRRRR
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# FLIPPERRRRRRRRRemoving outliers with method FLIP
#
# Removing outliers with method FLIP
# FLIPPERRRRRRRR
# Removing outliers with method FLIP
# FLIPPERRRRRRRR
# Removing outliers with method FLIP
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# Removing outliers with method FLIP
# FLIPPERRRRRRRR
# Removing outliers with method FLIP
# FLIPPERRRRRRRR
# Removing outliers with method FLIP
# FLIPPERRRRRRRR
# Removing outliers with method FLIP
# FLIPPERRRRRRRR
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# Removing outliers with method G_MAD
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# FLIPPERRRRRRRR
# Removing outliers with method G_MAD
# FLIPPERRRRRRRR
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# FLIPPERRRRRRRR
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# Removing outliers with method FLIP
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# Removing outliers with method FLIP
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# FLIPPERRRRRRRR
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# Removing outliers with method G_MAD
# FLIPPERRRRRRRR
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# FLIPPERRRRRRRR
# Removing outliers with method G_MAD
# FLIPPERRRRRRRR
# Removing outliers with method G_MAD
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method MAD
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method MAD
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method QN
# Removing outliers with method SN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method SN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method QN
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method QN
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method QN
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method MMS
# Removing outliers with method VS
# Removing outliers with method MMS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method MMS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method FLIP
# Removing outliers with method VS
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method VS
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method VS
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# FLIPPERRRRRRRR
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# Removing outliers with method FLIP
# FLIPPERRRRRRRR
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# FLIPPERRRRRRRR
# Removing outliers with method G_MAD
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# Removing outliers with method FLIP
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method FLIP
# Removing outliers with method G_MAD
# FLIPPERRRRRRRR
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# FLIPPERRRRRRRR
# Removing outliers with method FLIP
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# FLIPPERRRRRRRR
# Removing outliers with method G_MAD
# FLIPPERRRRRRRR
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# FLIPPERRRRRRRR
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_ZS
# Removing outliers with method G_MAD
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_MAD
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_MAD
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method ZS
# Removing outliers with method G_ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method G_ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method G_ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method MLP7_ALL
# Removing outliers with method ZS
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method ZS
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method ZS
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method MAD
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method IQR
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method IQR
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method SN
# Removing outliers with method MAD
# Removing outliers with method MAD
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method MAD
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method MAD
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method QN
# Removing outliers with method SN
# Removing outliers with method SN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method SN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method SN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method MMS
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method QN
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method QN
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method VS
# Removing outliers with method MMS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method MMS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method MMS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method FLIP
# Removing outliers with method VS
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method VS
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# FLIPPERRRRRRRR
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# FLIPPERRRRRRRR
# Removing outliers with method FLIP
# Removing outliers with method VS
# Removing outliers with method FLIP
# FLIPPERRRRRRRR
# Removing outliers with method FLIP
# FLIPPERRRRRRRR
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# FLIPPERRRRRRRR
# Removing outliers with method FLIP
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# FLIPPERRRRRRRR
# Removing outliers with method FLIP
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# FLIPPERRRRRRRR
# Removing outliers with method G_MAD
# Removing outliers with method FLIP
# FLIPPERRRRRRRR
# Removing outliers with method FLIP
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# FLIPPERRRRRRRR
# Removing outliers with method FLIP
# FLIPPERRRRRRRR
# Removing outliers with method G_MAD
# FLIPPERRRRRRRR
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# FLIPPERRRRRRRR
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# FLIPPERRRRRRRR
# Removing outliers with method FLIP
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# FLIPPERRRRRRRR
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_ZS
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_MAD
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_MAD
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method ZS
# Removing outliers with method G_ZS
# Removing outliers with method ZS
# Removing outliers with method G_ZS
# Removing outliers with method ZS
# Removing outliers with method G_ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method G_ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method ZS
# Removing outliers with method MLP7_ALL
# Removing outliers with method ZS
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method ZS
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method MAD
# ...
# FLIPPERRRRRRRR
# Removing outliers with method ZS
# Removing outliers with method VS
# Removing outliers with method G_MAD
# Removing outliers with method SN
# Removing outliers with method MLP7_ALL
# Removing outliers with method SN
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method MAD
# Removing outliers with method G_MAD
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method ZS
# Removing outliers with method IQR
# Removing outliers with method G_MAD
# FLIPPERRRRRRRR
# Removing outliers with method MMS
# Removing outliers with method FLIP
# FLIPPERRRRRRRR
# Removing outliers with method G_ZS
# Removing outliers with method MLP7_ALL
# Removing outliers with method SN
# Removing outliers with method QN
# FLIPPERRRRRRRR
# Removing outliers with method G_ZS
# Removing outliers with method MLP7_ALL
# Removing outliers with method QN
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method FLIP
# Removing outliers with method IQR
# Removing outliers with method SN
# Removing outliers with method G_ZS
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method IQR
# FLIPPERRRRRRRR
# Removing outliers with method MAD
# Removing outliers with method MLP7_ALL
# Removing outliers with method G_ZS
# Removing outliers with method G_MAD
# Removing outliers with method VS
# Removing outliers with method ZS
# Removing outliers with method QN
# Removing outliers with method IQR
# Removing outliers with method ZS
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method IQR
# Removing outliers with method G_MAD
# Removing outliers with method QN
# Removing outliers with method MAD
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method G_ZS
# Removing outliers with method ZS
# Removing outliers with method G_ZS
# Removing outliers with method IQR
# Removing outliers with method MAD
# Removing outliers with method ZS
# Removing outliers with method IQR
# Removing outliers with method SN
# Removing outliers with method G_ZS
# Removing outliers with method MLP7_ALL
# Removing outliers with method FLIP
# Removing outliers with method MMS
# Removing outliers with method IQR
# Removing outliers with method MAD
# Removing outliers with method MLP7_ALL
# Removing outliers with method VS
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method VS
# Removing outliers with method MAD
# Removing outliers with method G_ZS
# FLIPPERRRRRRRR
# Removing outliers with method SN
# Removing outliers with method MMS
# Removing outliers with method ZS
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method ZS
# Removing outliers with method MLP7_ALL
# Removing outliers with method MAD
# Removing outliers with method SN
# Removing outliers with method IQR
# Removing outliers with method MLP7_ALL
# Removing outliers with method QN
# Removing outliers with method MAD
# Removing outliers with method ZS
# Removing outliers with method G_MAD
# Removing outliers with method VS
# Removing outliers with method IQR
# Removing outliers with method MAD
# Removing outliers with method SN
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method SN
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method ZS
# Removing outliers with method QN
# Removing outliers with method VS
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method SN
# Removing outliers with method IQR
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# Removing outliers with method QN
# Removing outliers with method MAD
# Removing outliers with method MMS
# Removing outliers with method MLP7_ALL
# Removing outliers with method SN
# Removing outliers with method G_ZS
# Removing outliers with method FLIP
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method MAD
# Removing outliers with method SN
# Removing outliers with method QN
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method QN
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# FLIPPERRRRRRRR
# Removing outliers with method MLP7_ALL
# Removing outliers with method MMS
# Removing outliers with method FLIP
# Removing outliers with method QN
# Removing outliers with method MAD
# Removing outliers with method MMS
# Removing outliers with method SN
# Removing outliers with method IQR
# FLIPPERRRRRRRR
# Removing outliers with method VS
# Removing outliers with method QN
# Removing outliers with method IQR
# Removing outliers with method ZS
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method G_MAD
# Removing outliers with method SN
# Removing outliers with method QN
# Removing outliers with method MMS
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method MMS
# Removing outliers with method G_ZS
# Removing outliers with method IQR
# Removing outliers with method G_ZS
# Removing outliers with method VS
# Removing outliers with method G_MAD
# Removing outliers with method MMS
# Removing outliers with method SN
# Removing outliers with method IQR
# Removing outliers with method VS
# Removing outliers with method QN
# Removing outliers with method MAD
# Removing outliers with method FLIP
# Removing outliers with method MMS
# Removing outliers with method MAD
# Removing outliers with method MLP7_ALL
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method G_ZS
# Removing outliers with method QN
# Removing outliers with method MMS
# Removing outliers with method VS
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method VS
# FLIPPERRRRRRRR
# Removing outliers with method ZS
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method MAD
# Removing outliers with method ZS
# Removing outliers with method FLIP
# Removing outliers with method G_ZS
# Removing outliers with method VS
# Removing outliers with method QN
# Removing outliers with method MAD
# Removing outliers with method IQR
# Removing outliers with method MMS
# Removing outliers with method FLIP
# FLIPPERRRRRRRR
# Removing outliers with method SN
# Removing outliers with method VS
# Removing outliers with method G_MAD
# Removing outliers with method SN
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method ZS
# FLIPPERRRRRRRR
# Removing outliers with method MMS
# Removing outliers with method VS
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method IQR
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method MLP7_ALL
# Removing outliers with method MAD
# Removing outliers with method SN
# Removing outliers with method MLP7_ALL
# Removing outliers with method MAD
# Removing outliers with method G_MAD
# Removing outliers with method ZS
# Removing outliers with method MMS
# Removing outliers with method FLIP
# FLIPPERRRRRRRR
# Removing outliers with method SN
# FLIPPERRRRRRRR
# Removing outliers with method MAD
# Removing outliers with method G_MAD
# Removing outliers with method VS
# Removing outliers with method QN
# Removing outliers with method FLIP
# Removing outliers with method QN
# FLIPPERRRRRRRR
# Removing outliers with method G_ZS
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method MLP7_ALL
# Removing outliers with method VS
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method FLIP
# Removing outliers with method MAD
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# FLIPPERRRRRRRR
# Removing outliers with method SN
# Removing outliers with method QN
# Removing outliers with method SN
# Removing outliers with method G_ZS
# Removing outliers with method MLP7_ALL
# FLIPPERRRRRRRR
# Removing outliers with method G_MAD
# Removing outliers with method VS
# Removing outliers with method QN
# Removing outliers with method SN
# Removing outliers with method IQR
# Removing outliers with method G_ZS
# Removing outliers with method FLIP
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method ZS
# Removing outliers with method G_MAD
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# FLIPPERRRRRRRR
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method FLIP
# Removing outliers with method G_MAD
# Removing outliers with method G_ZS
# Removing outliers with method SN
# Removing outliers with method G_ZS
# Removing outliers with method MMS
# Removing outliers with method QN
# Removing outliers with method QN
# Removing outliers with method ZS
# Removing outliers with method G_ZS
# FLIPPERRRRRRRR
# Removing outliers with method FLIP
# Removing outliers with method MMS
# Removing outliers with method QN
# Removing outliers with method G_MAD
# Removing outliers with method MAD
# Removing outliers with method ZS
# Removing outliers with method VS
# Removing outliers with method VS
# Removing outliers with method MLP7_ALL
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method G_ZS
# FLIPPERRRRRRRR
# Removing outliers with method IQR
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method G_ZS
# Removing outliers with method G_MAD
# Removing outliers with method IQR
# Removing outliers with method ZS
# Removing outliers with method QN
# Removing outliers with method ZS
# Removing outliers with method MMS
# Removing outliers with method VS
# Removing outliers with method MLP7_ALL
# Removing outliers with method MMS
# Removing outliers with method ZS
# Removing outliers with method VS
# Removing outliers with method G_MAD
# Removing outliers with method MMS
# Removing outliers with method G_ZS
# Removing outliers with method SN
# Removing outliers with method MLP7_ALL
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method ZS
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method MAD
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method ZS
# Removing outliers with method G_ZS
# FLIPPERRRRRRRR
# Removing outliers with method MLP7_ALL
# Removing outliers with method IQR
# Removing outliers with method MLP7_ALL
# Removing outliers with method MAD
# Removing outliers with method MMS
# FLIPPERRRRRRRR
# Removing outliers with method VS
# Removing outliers with method FLIP
# Removing outliers with method VS
# Removing outliers with method MLP7_ALL
# Removing outliers with method G_ZS
# Removing outliers with method FLIP
# Removing outliers with method VS
# Removing outliers with method QN
# Removing outliers with method ZS
# FLIPPERRRRRRRR
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# Removing outliers with method MLP7_ALL
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# FLIPPERRRRRRRR
# Removing outliers with method SN
# Removing outliers with method MLP7_ALL
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method ZS
# Removing outliers with method MAD
# Removing outliers with method VS
# Removing outliers with method SN
# Removing outliers with method FLIP
# Removing outliers with method G_MAD
# Removing outliers with method FLIP
# Removing outliers with method ZS
# FLIPPERRRRRRRR
# Removing outliers with method G_MAD
# Removing outliers with method FLIP
# Removing outliers with method G_ZS
# Removing outliers with method MLP7_ALL
# Removing outliers with method MMS
# FLIPPERRRRRRRR
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method G_ZS
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# FLIPPERRRRRRRR
# Removing outliers with method MLP7_ALL
# Removing outliers with method QN
# Removing outliers with method SN
# Removing outliers with method FLIP
# Removing outliers with method QN
# Removing outliers with method G_MAD
# Removing outliers with method G_ZS
# Removing outliers with method G_MAD
# Removing outliers with method MLP7_ALL
# FLIPPERRRRRRRR
# Removing outliers with method G_ZS
# Removing outliers with method G_MAD
# Removing outliers with method ZS
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method VS
# Removing outliers with method ZS
# Removing outliers with method QN
# Removing outliers with method G_MAD
# Removing outliers with method MMS
# Removing outliers with method MMS
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method MLP7_ALL
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method G_ZS
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method FLIP
# Removing outliers with method MLP7_ALL
# Removing outliers with method MMS
# Removing outliers with method G_ZS
# Removing outliers with method VS
# Removing outliers with method VS
# FLIPPERRRRRRRR
# Removing outliers with method ZS
# Removing outliers with method MLP7_ALL
# Removing outliers with method ZS
# Removing outliers with method MLP7_ALL
# Removing outliers with method ZS
# Removing outliers with method G_MAD
# Removing outliers with method VS
# Removing outliers with method ZS
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method FLIP
# Removing outliers with method FLIP
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# FLIPPERRRRRRRR
# FLIPPERRRRRRRR
# Removing outliers with method MLP7_ALL
# Removing outliers with method G_ZS
# WARNING:root:A single handedness covariate was found. The handedness covariate will be ignored.
# Removing outliers with method FLIP
# Removing outliers with method MLP7_ALL
# Removing outliers with method G_MAD
# Removing outliers with method G_MAD
# FLIPPERRRRRRRR
# Removing outliers with method ZS
# Removing outliers with method G_MAD
# Removing outliers with method G_ZS
# Removing outliers with method G_ZS
# Removing outliers with method MLP7_ALL
# Removing outliers with method G_ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method ZS
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL
# Removing outliers with method MLP7_ALL

# %%
harmonization_method = "covbat"
analyse_method(sample_sizes, disease_ratios, num_tests, ALL_METHODS, diseases, metrics, harmonization_method, SYNTHETIC_SITES_VERSION, n_jobs=n_jobs_number)
# Out:
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Removing outliers with method IQR
# Traceback (most recent call last):
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/scripts/combat_quick_fit.py", line 281, in <module>
#     main()
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/scripts/combat_quick_fit.py", line 274, in main
#     QC.fit(ref_data, mov_data, args.hc)
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/clinical_combat/harmonization/QuickCombatCovBat.py", line 126, in fit
#     residual_mov, _ = self._compute_residual_and_expected(design_mov, y_mov, "mov")
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/clinical_combat/harmonization/QuickCombatCovBat.py", line 278, in _compute_residual_and_expected
#     residual[:, i] = z_star * self.sigma[i] * self.delta_ref[i]
# ValueError: could not broadcast input array from shape (100,) into shape (99,)
# Traceback (most recent call last):
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/scripts/combat_quick_fit.py", line 281, in <module>
#     main()
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/scripts/combat_quick_fit.py", line 274, in main
#     QC.fit(ref_data, mov_data, args.hc)
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/clinical_combat/harmonization/QuickCombatCovBat.py", line 126, in fit
#     residual_mov, _ = self._compute_residual_and_expected(design_mov, y_mov, "mov")
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/clinical_combat/harmonization/QuickCombatCovBat.py", line 278, in _compute_residual_and_expected
#     residual[:, i] = z_star * self.sigma[i] * self.delta_ref[i]
# ValueError: could not broadcast input array from shape (98,) into shape (99,)
# Traceback (most recent call last):
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/scripts/combat_quick_fit.py", line 281, in <module>
#     main()
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/scripts/combat_quick_fit.py", line 274, in main
#     QC.fit(ref_data, mov_data, args.hc)
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/clinical_combat/harmonization/QuickCombatCovBat.py", line 126, in fit
#     residual_mov, _ = self._compute_residual_and_expected(design_mov, y_mov, "mov")
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/clinical_combat/harmonization/QuickCombatCovBat.py", line 278, in _compute_residual_and_expected
#     residual[:, i] = z_star * self.sigma[i] * self.delta_ref[i]
# ValueError: could not broadcast input array from shape (100,) into shape (98,)
# Traceback (most recent call last):
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/scripts/combat_quick_fit.py", line 281, in <module>
#     main()
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/scripts/combat_quick_fit.py", line 274, in main
#     QC.fit(ref_data, mov_data, args.hc)
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/clinical_combat/harmonization/QuickCombatCovBat.py", line 126, in fit
#     residual_mov, _ = self._compute_residual_and_expected(design_mov, y_mov, "mov")
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/clinical_combat/harmonization/QuickCombatCovBat.py", line 278, in _compute_residual_and_expected
#     residual[:, i] = z_star * self.sigma[i] * self.delta_ref[i]
# ValueError: could not broadcast input array from shape (100,) into shape (99,)
# Traceback (most recent call last):
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/scripts/combat_quick_fit.py", line 281, in <module>
#     main()
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/scripts/combat_quick_fit.py", line 274, in main
#     QC.fit(ref_data, mov_data, args.hc)
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/clinical_combat/harmonization/QuickCombatCovBat.py", line 126, in fit
#     residual_mov, _ = self._compute_residual_and_expected(design_mov, y_mov, "mov")
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/clinical_combat/harmonization/QuickCombatCovBat.py", line 278, in _compute_residual_and_expected
#     residual[:, i] = z_star * self.sigma[i] * self.delta_ref[i]
# ValueError: could not broadcast input array from shape (99,) into shape (100,)
# Traceback (most recent call last):
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/scripts/combat_quick_fit.py", line 281, in <module>
#     main()
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/scripts/combat_quick_fit.py", line 274, in main
#     QC.fit(ref_data, mov_data, args.hc)
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/clinical_combat/harmonization/QuickCombatCovBat.py", line 126, in fit
#     residual_mov, _ = self._compute_residual_and_expected(design_mov, y_mov, "mov")
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/clinical_combat/harmonization/QuickCombatCovBat.py", line 278, in _compute_residual_and_expected
#     residual[:, i] = z_star * self.sigma[i] * self.delta_ref[i]
# ValueError: could not broadcast input array from shape (100,) into shape (99,)
# Traceback (most recent call last):
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/scripts/combat_quick_fit.py", line 281, in <module>
#     main()
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/scripts/combat_quick_fit.py", line 274, in main
#     QC.fit(ref_data, mov_data, args.hc)
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/clinical_combat/harmonization/QuickCombatCovBat.py", line 126, in fit
#     residual_mov, _ = self._compute_residual_and_expected(design_mov, y_mov, "mov")
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/clinical_combat/harmonization/QuickCombatCovBat.py", line 278, in _compute_residual_and_expected
#     residual[:, i] = z_star * self.sigma[i] * self.delta_ref[i]
# ValueError: could not broadcast input array from shape (100,) into shape (98,)
# Traceback (most recent call last):
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/scripts/combat_quick_fit.py", line 281, in <module>
#     main()
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/scripts/combat_quick_fit.py", line 274, in main
#     QC.fit(ref_data, mov_data, args.hc)
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/clinical_combat/harmonization/QuickCombatCovBat.py", line 126, in fit
#     residual_mov, _ = self._compute_residual_and_expected(design_mov, y_mov, "mov")
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/clinical_combat/harmonization/QuickCombatCovBat.py", line 278, in _compute_residual_and_expected
#     residual[:, i] = z_star * self.sigma[i] * self.delta_ref[i]
# ValueError: could not broadcast input array from shape (98,) into shape (100,)
# Traceback (most recent call last):
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/scripts/combat_quick_fit.py", line 281, in <module>
#     main()
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/scripts/combat_quick_fit.py", line 274, in main
#     QC.fit(ref_data, mov_data, args.hc)
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/clinical_combat/harmonization/QuickCombatCovBat.py", line 126, in fit
#     residual_mov, _ = self._compute_residual_and_expected(design_mov, y_mov, "mov")
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/clinical_combat/harmonization/QuickCombatCovBat.py", line 278, in _compute_residual_and_expected
#     residual[:, i] = z_star * self.sigma[i] * self.delta_ref[i]
# ValueError: could not broadcast input array from shape (98,) into shape (96,)
# Traceback (most recent call last):
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/scripts/combat_quick_fit.py", line 281, in <module>
#     main()
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/scripts/combat_quick_fit.py", line 274, in main
#     QC.fit(ref_data, mov_data, args.hc)
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/clinical_combat/harmonization/QuickCombatCovBat.py", line 126, in fit
#     residual_mov, _ = self._compute_residual_and_expected(design_mov, y_mov, "mov")
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/clinical_combat/harmonization/QuickCombatCovBat.py", line 278, in _compute_residual_and_expected
#     residual[:, i] = z_star * self.sigma[i] * self.delta_ref[i]
# ValueError: could not broadcast input array from shape (99,) into shape (97,)
# Traceback (most recent call last):
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/scripts/combat_quick_fit.py", line 281, in <module>
#     main()
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/scripts/combat_quick_fit.py", line 274, in main
#     QC.fit(ref_data, mov_data, args.hc)
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/clinical_combat/harmonization/QuickCombatCovBat.py", line 126, in fit
#     residual_mov, _ = self._compute_residual_and_expected(design_mov, y_mov, "mov")
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/clinical_combat/harmonization/QuickCombatCovBat.py", line 278, in _compute_residual_and_expected
#     residual[:, i] = z_star * self.sigma[i] * self.delta_ref[i]
# ValueError: could not broadcast input array from shape (98,) into shape (99,)
# Traceback (most recent call last):
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/scripts/combat_quick_fit.py", line 281, in <module>
#     main()
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/scripts/combat_quick_fit.py", line 274, in main
#     QC.fit(ref_data, mov_data, args.hc)
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/clinical_combat/harmonization/QuickCombatCovBat.py", line 126, in fit
#     residual_mov, _ = self._compute_residual_and_expected(design_mov, y_mov, "mov")
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/clinical_combat/harmonization/QuickCombatCovBat.py", line 278, in _compute_residual_and_expected
#     residual[:, i] = z_star * self.sigma[i] * self.delta_ref[i]
# ValueError: could not broadcast input array from shape (100,) into shape (99,)
# Traceback (most recent call last):
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/scripts/combat_quick_fit.py", line 281, in <module>
#     main()
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/scripts/combat_quick_fit.py", line 274, in main
#     QC.fit(ref_data, mov_data, args.hc)
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/clinical_combat/harmonization/QuickCombatCovBat.py", line 126, in fit
#     residual_mov, _ = self._compute_residual_and_expected(design_mov, y_mov, "mov")
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/clinical_combat/harmonization/QuickCombatCovBat.py", line 278, in _compute_residual_and_expected
#     residual[:, i] = z_star * self.sigma[i] * self.delta_ref[i]
# ValueError: could not broadcast input array from shape (99,) into shape (96,)
# Traceback (most recent call last):
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/scripts/combat_quick_fit.py", line 281, in <module>
#     main()
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/scripts/combat_quick_fit.py", line 274, in main
#     QC.fit(ref_data, mov_data, args.hc)
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/clinical_combat/harmonization/QuickCombatCovBat.py", line 126, in fit
#     residual_mov, _ = self._compute_residual_and_expected(design_mov, y_mov, "mov")
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/clinical_combat/harmonization/QuickCombatCovBat.py", line 278, in _compute_residual_and_expected
#     residual[:, i] = z_star * self.sigma[i] * self.delta_ref[i]
# ValueError: could not broadcast input array from shape (100,) into shape (95,)
# Traceback (most recent call last):
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/scripts/combat_quick_fit.py", line 281, in <module>
#     main()
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/scripts/combat_quick_fit.py", line 274, in main
#     QC.fit(ref_data, mov_data, args.hc)
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/clinical_combat/harmonization/QuickCombatCovBat.py", line 126, in fit
#     residual_mov, _ = self._compute_residual_and_expected(design_mov, y_mov, "mov")
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/clinical_combat/harmonization/QuickCombatCovBat.py", line 278, in _compute_residual_and_expected
#     residual[:, i] = z_star * self.sigma[i] * self.delta_ref[i]
# ValueError: could not broadcast input array from shape (98,) into shape (96,)
# Traceback (most recent call last):
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/scripts/combat_quick_fit.py", line 281, in <module>
#     main()
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/scripts/combat_quick_fit.py", line 274, in main
#     QC.fit(ref_data, mov_data, args.hc)
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/clinical_combat/harmonization/QuickCombatCovBat.py", line 126, in fit
#     residual_mov, _ = self._compute_residual_and_expected(design_mov, y_mov, "mov")
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/clinical_combat/harmonization/QuickCombatCovBat.py", line 278, in _compute_residual_and_expected
#     residual[:, i] = z_star * self.sigma[i] * self.delta_ref[i]
# ValueError: could not broadcast input array from shape (99,) into shape (100,)
# Traceback (most recent call last):
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/scripts/combat_quick_fit.py", line 281, in <module>
#     main()
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/scripts/combat_quick_fit.py", line 274, in main
#     QC.fit(ref_data, mov_data, args.hc)
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/clinical_combat/harmonization/QuickCombatCovBat.py", line 126, in fit
#     residual_mov, _ = self._compute_residual_and_expected(design_mov, y_mov, "mov")
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/clinical_combat/harmonization/QuickCombatCovBat.py", line 278, in _compute_residual_and_expected
#     residual[:, i] = z_star * self.sigma[i] * self.delta_ref[i]
# ValueError: could not broadcast input array from shape (100,) into shape (99,)
# Traceback (most recent call last):
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/scripts/combat_quick_fit.py", line 281, in <module>
#     main()
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/scripts/combat_quick_fit.py", line 274, in main
#     QC.fit(ref_data, mov_data, args.hc)
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/clinical_combat/harmonization/QuickCombatCovBat.py", line 126, in fit
#     residual_mov, _ = self._compute_residual_and_expected(design_mov, y_mov, "mov")
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/clinical_combat/harmonization/QuickCombatCovBat.py", line 278, in _compute_residual_and_expected
#     residual[:, i] = z_star * self.sigma[i] * self.delta_ref[i]
# ValueError: could not broadcast input array from shape (99,) into shape (100,)
# Traceback (most recent call last):
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/scripts/combat_quick_fit.py", line 281, in <module>
#     main()
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/scripts/combat_quick_fit.py", line 274, in main
#     QC.fit(ref_data, mov_data, args.hc)
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/clinical_combat/harmonization/QuickCombatCovBat.py", line 126, in fit
#     residual_mov, _ = self._compute_residual_and_expected(design_mov, y_mov, "mov")
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/clinical_combat/harmonization/QuickCombatCovBat.py", line 278, in _compute_residual_and_expected
#     residual[:, i] = z_star * self.sigma[i] * self.delta_ref[i]
# ValueError: could not broadcast input array from shape (96,) into shape (97,)
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/.robust/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 463, in _process_worker
#     r = call_item()
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/.robust/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 291, in __call__
#     return self.fn(*self.args, **self.kwargs)
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/.robust/lib/python3.10/site-packages/joblib/parallel.py", line 598, in __call__
#     return [func(*args, **kwargs)
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/.robust/lib/python3.10/site-packages/joblib/parallel.py", line 598, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/tmp/ipykernel_169220/4007834995.py", line 176, in process_analysis
#   File "/tmp/ipykernel_169220/4007834995.py", line 82, in analyse_site
#   File "/tmp/ipykernel_169220/4007834995.py", line 11, in harmonize
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/robust_evaluation_tools/robust_harmonization.py", line 93, in apply
#     combat_quick_apply.apply(mov_data_file, model_filename, output_filename)
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/scripts/combat_quick_apply.py", line 84, in apply
#     QC = from_model_filename(model)
#   File "/home/local/USHERBROOKE/davy3001/Documents/COMBAT/Jodoin/Combat_robust/clinical_combat/harmonization/__init__.py", line 99, in from_model_filename
#     with open(model_filename) as f:
# FileNotFoundError: [Errno 2] No such file or directory: 'RESULTS/MAE_TEST/PROCESS_covbat/ALL/100_3/12/ad/IQR/ALL_100_patients_3_percent_12.ad.covbat.IQR.NoRWP.model.csv'
# """
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 harmonization_method = "covbat"
# ----> 2 analyse_method(sample_sizes, disease_ratios, num_tests, ALL_METHODS, diseases, metrics, harmonization_method, SYNTHETIC_SITES_VERSION, n_jobs=n_jobs_number)
#
# Cell In[3], line 260, in analyse_method(sample_sizes, disease_ratios, num_tests, robust_methods, diseases, metrics, harmonization_method, SYNTHETIC_SITES_VERSION, n_jobs)
#     250     num_tests = inferred_num_tests if num_tests is None else num_tests
#     252 tasks = [
#     253     (disease, sample_size, disease_ratio, num_test, harmonization_method, SYNTHETIC_SITES_VERSION, metrics, robust_methods)
#     254     for disease in diseases
#    (...)
#     257     for num_test in range(num_tests)
#     258 ]
# --> 260 Parallel(n_jobs=n_jobs)(delayed(process_analysis)(*task) for task in tasks)
#
# File ~/Documents/COMBAT/Jodoin/Combat_robust/.robust/lib/python3.10/site-packages/joblib/parallel.py:2007, in Parallel.__call__(self, iterable)
#    2001 # The first item from the output is blank, but it makes the interpreter
#    2002 # progress until it enters the Try/Except block of the generator and
#    2003 # reaches the first `yield` statement. This starts the asynchronous
#    2004 # dispatch of the tasks to the workers.
#    2005 next(output)
# -> 2007 return output if self.return_generator else list(output)
#
# File ~/Documents/COMBAT/Jodoin/Combat_robust/.robust/lib/python3.10/site-packages/joblib/parallel.py:1650, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1647     yield
#    1649     with self._backend.retrieval_context():
# -> 1650         yield from self._retrieve()
#    1652 except GeneratorExit:
#    1653     # The generator has been garbage collected before being fully
#    1654     # consumed. This aborts the remaining tasks if possible and warn
#    1655     # the user if necessary.
#    1656     self._exception = True
#
# File ~/Documents/COMBAT/Jodoin/Combat_robust/.robust/lib/python3.10/site-packages/joblib/parallel.py:1754, in Parallel._retrieve(self)
#    1747 while self._wait_retrieval():
#    1748
#    1749     # If the callback thread of a worker has signaled that its task
#    1750     # triggered an exception, or if the retrieval loop has raised an
#    1751     # exception (e.g. `GeneratorExit`), exit the loop and surface the
#    1752     # worker traceback.
#    1753     if self._aborting:
# -> 1754         self._raise_error_fast()
#    1755         break
#    1757     # If the next job is not ready for retrieval yet, we just wait for
#    1758     # async callbacks to progress.
#
# File ~/Documents/COMBAT/Jodoin/Combat_robust/.robust/lib/python3.10/site-packages/joblib/parallel.py:1789, in Parallel._raise_error_fast(self)
#    1785 # If this error job exists, immediately raise the error by
#    1786 # calling get_result. This job might not exists if abort has been
#    1787 # called directly or if the generator is gc'ed.
#    1788 if error_job is not None:
# -> 1789     error_job.get_result(self.timeout)
#
# File ~/Documents/COMBAT/Jodoin/Combat_robust/.robust/lib/python3.10/site-packages/joblib/parallel.py:745, in BatchCompletionCallBack.get_result(self, timeout)
#     739 backend = self.parallel._backend
#     741 if backend.supports_retrieve_callback:
#     742     # We assume that the result has already been retrieved by the
#     743     # callback thread, and is stored internally. It's just waiting to
#     744     # be returned.
# --> 745     return self._return_or_raise()
#     747 # For other backends, the main thread needs to run the retrieval step.
#     748 try:
#
# File ~/Documents/COMBAT/Jodoin/Combat_robust/.robust/lib/python3.10/site-packages/joblib/parallel.py:763, in BatchCompletionCallBack._return_or_raise(self)
#     761 try:
#     762     if self.status == TASK_ERROR:
# --> 763         raise self._result
#     764     return self._result
#     765 finally:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'RESULTS/MAE_TEST/PROCESS_covbat/ALL/100_3/12/ad/IQR/ALL_100_patients_3_percent_12.ad.covbat.IQR.NoRWP.model.csv'
